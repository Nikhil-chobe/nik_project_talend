# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\chobe\\Desktop\\Python\\covid_toy (1).csv")

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df.to_csv("C:\\Users\\chobe\\Desktop\\Python\\covid_toy (2).csv")

# %%
! pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.1/11.9 MB 656.4 kB/s eta 0:00:18
#      ---------------------------------------- 0.1/11.9 MB 1.0 MB/s eta 0:00:12
#       --------------------------------------- 0.2/11.9 MB 1.1 MB/s eta 0:00:12
#       --------------------------------------- 0.3/11.9 MB 1.2 MB/s eta 0:00:10
#      - -------------------------------------- 0.3/11.9 MB 1.3 MB/s eta 0:00:10
#      - -------------------------------------- 0.4/11.9 MB 1.4 MB/s eta 0:00:09
#      - -------------------------------------- 0.5/11.9 MB 1.5 MB/s eta 0:00:08
#      -- ------------------------------------- 0.6/11.9 MB 1.5 MB/s eta 0:00:08
#      -- ------------------------------------- 0.7/11.9 MB 1.6 MB/s eta 0:00:07
#      -- ------------------------------------- 0.8/11.9 MB 1.7 MB/s eta 0:00:07
# ...

# %%
import mysql.connector

# %%
import pandas as pd

# %%
conn=mysql.connector.connect(host='localhost',user='root',password ='',database='practice2')

# %%
pd.read_sql_query("select * from  update_toy_data",conn)
# Out:
# C:\Users\chobe\AppData\Local\Temp\ipykernel_13224\1786583781.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("select * from  update_toy_data",conn)
#     Column0  age  gender  fever   cough       city has_covid
# 0         0   60    Male  103.0    Mild    Kolkata        No
# 1         1   27    Male  100.0    Mild      Delhi       Yes
# 2         2   42    Male  101.0    Mild      Delhi        No
# 3         3   31  Female   98.0    Mild    Kolkata        No
# 4         4   65  Female  101.0    Mild     Mumbai        No
# ..      ...  ...     ...    ...     ...        ...       ...
# 85       95   12  Female  104.0    Mild  Bangalore        No
# 86       96   51  Female  101.0  Strong    Kolkata       Yes
# 87       97   20  Female  101.0    Mild  Bangalore        No
# ...

# %%
pd.read_sql_query("select * from update_toy_data where cough like 'Mild'",conn)
# Out:
# C:\Users\chobe\AppData\Local\Temp\ipykernel_13224\2738172738.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("select * from update_toy_data where cough like 'Mild'",conn)
#     Column0  age  gender  fever cough       city has_covid
# 0         0   60    Male  103.0  Mild    Kolkata        No
# 1         1   27    Male  100.0  Mild      Delhi       Yes
# 2         2   42    Male  101.0  Mild      Delhi        No
# 3         3   31  Female   98.0  Mild    Kolkata        No
# 4         4   65  Female  101.0  Mild     Mumbai        No
# 5         9   64  Female  101.0  Mild      Delhi        No
# 6        11   65  Female   98.0  Mild     Mumbai       Yes
# 7        13   64    Male  102.0  Mild  Bangalore       Yes
# 8        14   51    Male  104.0  Mild  Bangalore        No
# ...

# %%
pd.read_sql_query("select * from update_toy_data where fever>100",conn)
# Out:
# C:\Users\chobe\AppData\Local\Temp\ipykernel_13224\1324471845.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("select * from update_toy_data where fever>100",conn)
#     Column0  age  gender  fever   cough       city has_covid
# 0         0   60    Male  103.0    Mild    Kolkata        No
# 1         2   42    Male  101.0    Mild      Delhi        No
# 2         4   65  Female  101.0    Mild     Mumbai        No
# 3         6   14    Male  101.0  Strong  Bangalore        No
# 4         9   64  Female  101.0    Mild      Delhi        No
# 5        13   64    Male  102.0    Mild  Bangalore       Yes
# 6        14   51    Male  104.0    Mild  Bangalore        No
# 7        15   70    Male  103.0  Strong    Kolkata       Yes
# 8        16   69  Female  103.0    Mild    Kolkata       Yes
# ...
